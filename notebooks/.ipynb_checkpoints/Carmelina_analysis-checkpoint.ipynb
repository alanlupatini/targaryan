# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_demo = pd.read_csv('../data/Clean/df_demo_clean.csv')
df_experiment = pd.read_csv('../data/Clean/df_experiment_clean.csv')

# %%
print(df_demo.info())
print(df_demo.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70595 entries, 0 to 70594
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   client_id             70595 non-null  int64
#  1   client_tenure_years   70595 non-null  float64
#  2   client_tenure_months  70595 non-null  float64
#  3   client_age            70595 non-null  float64
#  4   gender                70595 non-null  object
#  5   num_accounts          70595 non-null  float64
#  6   balance               70595 non-null  float64
#  7   calls_6_months        70595 non-null  float64
#  8   logons_6_months       70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB
# None
#    client_id  client_tenure_years  client_tenure_months  client_age gender  \
# 0     836976                  6.0                  73.0        60.5      U
# 1    2304905                  7.0                  94.0        58.0      U
# ...

# %%
print(df_experiment.info())
print(df_experiment.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50500 entries, 0 to 50499
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  50500 non-null  int64
#  1   variation  50500 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 789.2+ KB
# None
#    client_id variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_demo.describe()
# Out:
#           client_id  client_tenure_years  client_tenure_months    client_age  \
# count  7.059500e+04         70595.000000          70595.000000  70595.000000
# mean   5.005021e+06            12.052950            150.659367     46.442248
# std    2.877269e+06             6.871819             82.089854     15.591162
# min    1.690000e+02             2.000000             33.000000     13.500000
# 25%    2.519604e+06             6.000000             82.000000     32.500000
# 50%    5.016969e+06            11.000000            136.000000     47.000000
# 75%    7.483064e+06            16.000000            192.000000     59.000000
# max    9.999839e+06            62.000000            749.000000     96.000000
#
#        num_accounts       balance  calls_6_months  logons_6_months
# count  70595.000000  7.059500e+04    70595.000000     70595.000000
# mean       2.255528  1.474452e+05        3.382478         5.566740
# std        0.534997  3.015087e+05        2.236580         2.353286
# ...

# %%
df_demo['gender'].value_counts()
# Out:
# gender
# U    24125
# M    23724
# F    22746
# Name: count, dtype: int64

# %%
df_demo['num_accounts'].value_counts()
# Out:
# num_accounts
# 2.0    55497
# 3.0    12529
# 4.0     2241
# 5.0      284
# 6.0       33
# 7.0        8
# 1.0        2
# 8.0        1
# Name: count, dtype: int64

# %%
df_demo['client_age'].value_counts()
# Out:
# client_age
# 58.5    859
# 55.5    830
# 29.5    829
# 28.5    827
# 57.5    826
#        ...
# 96.0      2
# 14.0      2
# 94.5      1
# 95.5      1
# 13.5      1
# Name: count, Length: 165, dtype: int64

# %%
mean_age = round(df_demo['client_age'].mean(), 1)
mean_age
# Out:
# np.float64(46.4)

# %%
median_age = df_demo['client_age'].median()
median_age
# Out:
# 47.0

# %%
min_age = df_demo['client_age'].min()
min_age
# Out:
# 13.5

# %%
max_age = df_demo['client_age'].max()
max_age
# Out:
# 96.0

# %%
# Tenure analysis
print(f"Mean tenure (years): {df_demo['client_tenure_years'].mean()")
print(f"Median tenure (years): {df_demo['client_tenure_years'].median():.1f}")
# Out:
# Mean tenure (years): 12.1
# Median tenure (years): 11.0
